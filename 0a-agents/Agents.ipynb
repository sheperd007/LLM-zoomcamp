# %%
# !pip install fastmcp
# !pip install minsearch
# Out:
# Requirement already satisfied: fastmcp in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.10.6)
# Requirement already satisfied: authlib>=1.5.2 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (1.6.1)
# Requirement already satisfied: cyclopts>=3.0.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (3.22.3)
# Requirement already satisfied: exceptiongroup>=1.2.2 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (0.28.1)
# Requirement already satisfied: mcp>=1.10.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (1.12.2)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (0.5.1)
# Requirement already satisfied: pydantic>=2.11.7 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.11.7)
# Requirement already satisfied: pyperclip>=1.9.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (1.9.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (1.1.1)
# Requirement already satisfied: rich>=13.9.4 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastmcp) (14.1.0)
# Requirement already satisfied: cryptography in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from authlib>=1.5.2->fastmcp) (45.0.5)
# Requirement already satisfied: attrs>=23.1.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cyclopts>=3.0.0->fastmcp) (25.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cyclopts>=3.0.0->fastmcp) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cyclopts>=3.0.0->fastmcp) (1.3.1)
# Requirement already satisfied: docutils in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp) (0.21.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from exceptiongroup>=1.2.2->fastmcp) (4.13.2)
# Requirement already satisfied: anyio in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.28.1->fastmcp) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.28.1->fastmcp) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.28.1->fastmcp) (1.0.9)
# Requirement already satisfied: idna in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.28.1->fastmcp) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (310)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (2.4.1)
# Requirement already satisfied: starlette>=0.27 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (0.47.2)
# Requirement already satisfied: uvicorn>=0.23.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp>=1.10.0->fastmcp) (0.35.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx>=0.28.1->fastmcp) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->fastmcp) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->fastmcp) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->fastmcp) (0.26.0)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=13.9.4->fastmcp) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=13.9.4->fastmcp) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp) (0.1.2)
# Requirement already satisfied: click>=7.0 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn>=0.23.1->mcp>=1.10.0->fastmcp) (8.2.1)
# Requirement already satisfied: colorama in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=7.0->uvicorn>=0.23.1->mcp>=1.10.0->fastmcp) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography->authlib>=1.5.2->fastmcp) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.14->cryptography->authlib>=1.5.2->fastmcp) (2.22)
# Collecting minsearch
#   Downloading minsearch-0.0.4-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from minsearch) (2.3.1)
# Collecting pandas (from minsearch)
#   Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn (from minsearch)
#   Downloading scikit_learn-1.7.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->minsearch) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->minsearch)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->minsearch)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\hamidandnavid\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas->minsearch) (1.17.0)
# Collecting scipy>=1.8.0 (from scikit-learn->minsearch)
#   Downloading scipy-1.16.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->minsearch)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->minsearch)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading minsearch-0.0.4-py3-none-any.whl (11 kB)
# Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.3 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.3 MB 2.3 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.3 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.3 MB 1.8 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.3 MB 1.8 MB/s eta 0:00:06
#    ------------ --------------------------- 3.7/11.3 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.3 MB 2.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.3 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.3 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.3 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 6.8/11.3 MB 2.2 MB/s eta 0:00:03
#    -------------------------- ------------- 7.6/11.3 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.3 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 2.1 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading scikit_learn-1.7.1-cp311-cp311-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.9 MB 6.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.9 MB 6.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.9 MB 6.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.9 MB 1.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/8.9 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.4/8.9 MB 1.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.6/8.9 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/8.9 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.7/8.9 MB 1.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.9 MB 1.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.9 MB 1.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.9/8.9 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/8.9 MB 1.6 MB/s eta 0:00:03
#    --------------------- ------------------ 4.7/8.9 MB 1.6 MB/s eta 0:00:03
#    ------------------------ --------------- 5.5/8.9 MB 1.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/8.9 MB 1.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/8.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 6.8/8.9 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 6.8/8.9 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 7.3/8.9 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 7.9/8.9 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/8.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 1.6 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.16.0-cp311-cp311-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.6 MB 16.4 MB/s eta 0:00:03
#     --------------------------------------- 0.8/38.6 MB 1.5 MB/s eta 0:00:25
#    - -------------------------------------- 1.0/38.6 MB 1.5 MB/s eta 0:00:26
#    - -------------------------------------- 1.3/38.6 MB 1.7 MB/s eta 0:00:22
#    - -------------------------------------- 1.6/38.6 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.4/38.6 MB 1.8 MB/s eta 0:00:21
#    -- ------------------------------------- 2.4/38.6 MB 1.8 MB/s eta 0:00:21
#    -- ------------------------------------- 2.4/38.6 MB 1.8 MB/s eta 0:00:21
#    -- ------------------------------------- 2.9/38.6 MB 1.5 MB/s eta 0:00:24
#    -- ------------------------------------- 2.9/38.6 MB 1.5 MB/s eta 0:00:24
#    -- ------------------------------------- 2.9/38.6 MB 1.5 MB/s eta 0:00:24
#    ---- ----------------------------------- 3.9/38.6 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 4.2/38.6 MB 1.6 MB/s eta 0:00:22
#    ---- ----------------------------------- 4.2/38.6 MB 1.6 MB/s eta 0:00:22
#    ---- ----------------------------------- 4.2/38.6 MB 1.6 MB/s eta 0:00:22
#    ----- ---------------------------------- 5.5/38.6 MB 1.7 MB/s eta 0:00:20
#    ----- ---------------------------------- 5.5/38.6 MB 1.7 MB/s eta 0:00:20
#    ------ --------------------------------- 6.0/38.6 MB 1.6 MB/s eta 0:00:21
#    ------ --------------------------------- 6.0/38.6 MB 1.6 MB/s eta 0:00:21
#    ------ --------------------------------- 6.6/38.6 MB 1.6 MB/s eta 0:00:20
#    ------- -------------------------------- 6.8/38.6 MB 1.6 MB/s eta 0:00:21
#    ------- -------------------------------- 7.6/38.6 MB 1.7 MB/s eta 0:00:19
#    ------- -------------------------------- 7.6/38.6 MB 1.7 MB/s eta 0:00:19
#    -------- ------------------------------- 7.9/38.6 MB 1.6 MB/s eta 0:00:20
#    -------- ------------------------------- 8.4/38.6 MB 1.7 MB/s eta 0:00:19
#    --------- ------------------------------ 8.9/38.6 MB 1.7 MB/s eta 0:00:18
#    --------- ------------------------------ 8.9/38.6 MB 1.7 MB/s eta 0:00:18
#    --------- ------------------------------ 9.4/38.6 MB 1.6 MB/s eta 0:00:18
#    --------- ------------------------------ 9.4/38.6 MB 1.6 MB/s eta 0:00:18
#    ---------- ----------------------------- 10.5/38.6 MB 1.7 MB/s eta 0:00:17
#    ---------- ----------------------------- 10.5/38.6 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 10.7/38.6 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 11.0/38.6 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 11.3/38.6 MB 1.6 MB/s eta 0:00:17
#    ----------- ---------------------------- 11.5/38.6 MB 1.6 MB/s eta 0:00:17
#    ------------ --------------------------- 12.3/38.6 MB 1.7 MB/s eta 0:00:16
#    ------------ --------------------------- 12.3/38.6 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 13.1/38.6 MB 1.7 MB/s eta 0:00:16
#    -------------- ------------------------- 13.6/38.6 MB 1.7 MB/s eta 0:00:15
#    -------------- ------------------------- 14.2/38.6 MB 1.7 MB/s eta 0:00:15
#    -------------- ------------------------- 14.4/38.6 MB 1.7 MB/s eta 0:00:14
#    --------------- ------------------------ 14.7/38.6 MB 1.7 MB/s eta 0:00:14
#    ---------------- ----------------------- 15.5/38.6 MB 1.8 MB/s eta 0:00:14
#    ---------------- ----------------------- 15.7/38.6 MB 1.8 MB/s eta 0:00:13
#    ---------------- ----------------------- 16.0/38.6 MB 1.8 MB/s eta 0:00:13
#    ----------------- ---------------------- 16.8/38.6 MB 1.8 MB/s eta 0:00:13
#    ----------------- ---------------------- 17.0/38.6 MB 1.8 MB/s eta 0:00:13
#    ------------------ --------------------- 17.8/38.6 MB 1.8 MB/s eta 0:00:12
#    ------------------- -------------------- 18.9/38.6 MB 1.9 MB/s eta 0:00:11
#    ------------------- -------------------- 19.1/38.6 MB 1.9 MB/s eta 0:00:11
#    -------------------- ------------------- 19.4/38.6 MB 1.9 MB/s eta 0:00:11
#    -------------------- ------------------- 20.2/38.6 MB 1.9 MB/s eta 0:00:10
#    --------------------- ------------------ 20.4/38.6 MB 1.9 MB/s eta 0:00:10
#    ---------------------- ----------------- 21.5/38.6 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 21.8/38.6 MB 2.0 MB/s eta 0:00:09
#    ----------------------- ---------------- 22.3/38.6 MB 2.0 MB/s eta 0:00:09
#    ------------------------ --------------- 23.3/38.6 MB 2.0 MB/s eta 0:00:08
#    ------------------------ --------------- 23.9/38.6 MB 2.0 MB/s eta 0:00:08
#    ------------------------- -------------- 24.9/38.6 MB 2.1 MB/s eta 0:00:07
#    ------------------------- -------------- 24.9/38.6 MB 2.1 MB/s eta 0:00:07
#    -------------------------- ------------- 25.4/38.6 MB 2.1 MB/s eta 0:00:07
#    --------------------------- ------------ 26.2/38.6 MB 2.1 MB/s eta 0:00:06
#    --------------------------- ------------ 26.5/38.6 MB 2.1 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.5/38.6 MB 2.1 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.5/38.6 MB 2.1 MB/s eta 0:00:06
#    ------------------------------ --------- 29.4/38.6 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 29.4/38.6 MB 2.2 MB/s eta 0:00:05
#    ------------------------------- -------- 30.4/38.6 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 30.4/38.6 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 30.7/38.6 MB 2.2 MB/s eta 0:00:04
#    --------------------------------- ------ 32.0/38.6 MB 2.2 MB/s eta 0:00:03
#    --------------------------------- ------ 32.0/38.6 MB 2.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.0/38.6 MB 2.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.6/38.6 MB 2.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.6/38.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/38.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.6 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------------------- - 37.2/38.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 2.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, scipy, joblib, scikit-learn, pandas, minsearch
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ---------------------------------------- 8/8 [minsearch]
#
# Successfully installed joblib-1.5.1 minsearch-0.0.4 pandas-2.3.1 pytz-2025.2 scikit-learn-1.7.1 scipy-1.16.0 threadpoolctl-3.6.0 tzdata-2025.2

# %%
import random

known_weather_data = {
    'berlin': 20.0
}

def get_weather(city: str) -> float:
    city = city.strip().lower()

    if city in known_weather_data:
        return known_weather_data[city]

    return round(random.uniform(-5, 35), 1)

# %%
get_weather("berlin")
# Out:
# 20.0

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/rag-agents-workshop/refs/heads/main/chat_assistant.py
# Out:
# C:\Users\HamidandNavid\AppData\Local\Temp\ipykernel_3792\1164266753.py:24: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   es_client.indices.create(index=index_name, body=index_settings)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'course-questions'})

# %%
from openai import OpenAI
client = OpenAI(api_key='')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from openai import OpenAI
#       2 client = OpenAI(api_key='')
#
# ModuleNotFoundError: No module named 'openai'

# %%
import chat_assistant

tools = chat_assistant.Tools()
tools.add_tool(get_weather, get_weather_tool)

# %%
tools.get_tools()
# Out:
# C:\Users\HamidandNavid\AppData\Local\Temp\ipykernel_3792\2121495424.py:18: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(index=index_name, body=search_query)
# Top result score: 44.50556

# %%
developer_prompt = """
You're a weather assistant.
You're given a question about the weather of a city and your task is to answer it.

Use FAQ if your own knowledge is not sufficient to answer the question.

At the end of each response, ask the user a follow up question based on your answer.
""".strip()

chat_interface = chat_assistant.ChatInterface()

chat = chat_assistant.ChatAssistant(
    tools=tools,
    developer_prompt=developer_prompt,
    chat_interface=chat_interface,
    client=client
)
# Out:
# C:\Users\HamidandNavid\AppData\Local\Temp\ipykernel_3792\3247290569.py:22: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(
# Third question: How do I copy files from a different folder into docker container’s working directory?

# %%
chat.run()

# %%
def set_weather(city: str, temp: float) -> None:
    city = city.strip().lower()
    known_weather_data[city] = temp
    return 'OK'
# Out:
# C:\Users\HamidandNavid\AppData\Local\Temp\ipykernel_3792\3049096591.py:22: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   response = es_client.search(index=index_name, body=search_query)
# Prompt length: 1821

# %%
# !python /content/weather_server.py
# Out:
# '\nYou\'re a course teaching assistant. Answer the QUESTION based on the CONTEXT from the FAQ database.\nUse only the facts from the CONTEXT when answering the QUESTION.\n\nQUESTION: How do I execute a command in a running docker container?\n\nCONTEXT:\n[{\'text\': \'Launch the container image in interactive mode and overriding the entrypoint, so that it starts a bash command.\\ndocker run -it --entrypoint bash \\nIf the container is already running, execute a command in the specific container:\\ndocker ps (find the container-id)\\ndocker exec -it <container-id> bash\\n(Marcos MJD)\', \'section\': \'5. Deploying Machine Learning Models\', \'question\': \'How do I debug a docker container?\', \'course\': \'machine-learning-zoomcamp\'}, {\'text\': "You can copy files from your local machine into a Docker container using the docker cp command. Here\'s how to do it:\\nTo copy a file or directory from your local machine into a running Docker container, you can use the `docker cp command`. The basic syntax is as follows:\\ndocker cp /path/to/local/file_or_directory container_id:/path/in/container\\nHrithik Kumar Advani", \'section\': \'5. Deploying Machine Learning Models\', \'question\': \'How do I copy files from my local machine to docker container?\', \'course\': \'machine-learning-zoomcamp\'}, {\'text\': \'You can copy files from your local machine into a Docker container using the docker cp command. Here\\\'s how to do it:\\nIn the Dockerfile, you can provide the folder containing the files that you want to copy over. The basic syntax is as follows:\\nCOPY ["src/predict.py", "models/xgb_model.bin", "./"]\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\tGopakumar Gopinathan\', \'section\': \'5. Deploying Machine Learning Models\', \'question\': \'How do I copy files from a different folder into docker container’s working directory?\', \'course\': \'machine-learning-zoomcamp\'}]\n'
